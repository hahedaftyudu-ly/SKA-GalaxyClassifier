# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
resnet18_train_loss = [0.192042, 0.093768, 0.076213, 0.066496, 0.057847, 0.050726, 0.042538, 0.017920, 0.011101,
                       0.007791,
                       0.005911, 0.004693, 0.003716, 0.003194, 0.002392, 0.002255, 0.002370, 0.002321, 0.002307,
                       0.002453]
resnet18_val_loss = [0.090732, 0.071994, 0.070195, 0.065357, 0.103215, 0.076338, 0.088816, 0.075911, 0.077485, 0.084704,
                     0.084704, 0.097564, 0.094597, 0.096502, 0.098066, 0.102936, 0.099543, 0.098091, 0.100158, 0.100360]

resnet18_train_acc = [0.935821, 0.971069, 0.976681, 0.979217, 0.981882, 0.984034, 0.986522, 0.994871, 0.997231,
                      0.998282,
                      0.998740, 0.999133, 0.999486, 0.999607, 0.999671, 0.999791, 0.999703, 0.999799, 0.999783,
                      0.999655]
resnet18_val_acc = [0.976375, 0.977747, 0.979770, 0.980854, 0.966187, 0.977531, 0.978398, 0.982010, 0.982227, 0.981649,
                    0.980926, 0.980348, 0.980854, 0.981576, 0.980637, 0.980709, 0.980854, 0.981287, 0.980998, 0.980420]

epochs = range(1, 21)

# %%
ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %%
plt.plot(epochs, resnet18_train_loss, label="Training loss")
plt.plot(epochs, resnet18_val_loss, 'g', label="Validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
