# %%
import matplotlib.pyplot as plt

# %%
zwarning_cleaned_SDSS_cat = {'GALAXY': 55603  , 'STAR': 14927 , 'QSO': 11068}
classes = zwarning_cleaned_SDSS_cat.keys()
counts = zwarning_cleaned_SDSS_cat.values()

# %%
fig, ax = plt.subplots()
bar_width = 0.7
rects = ax.bar(range(3), counts, bar_width)
ax.set_xticks(range(3), classes)
ax.bar_label(rects, padding=3)
fig.tight_layout()

# %%
zw_data_galaxy = {'0': 722, '1': 48, '4': 63, '5': 982, '134': 1, '135': 3}
zw_data_star = {'0': 50, '1': 167, '4': 46, '5': 1380, '8': 5, '9': 185, '12': 33, '13': 1144, '16': 1}
zw_data_QSO = {'0': 9, '1': 59, '4': 108, '5': 2896, '21': 1, '64': 2, '65': 2, '68': 7, '69': 52}
